# %% [markdown]
# ## Scraping the UIC academic calendar
#
# `https://catalog.uic.edu/ucat/academic-calendar/`

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
with urlopen("https://catalog.uic.edu/ucat/academic-calendar/") as r:
    with open("calendar.html","wb") as fp:
        fp.write(r.read()) # save a local copy of the UIC calendar page

# %%
with open("calendar.html","rb") as fp:
    soup = BeautifulSoup(fp, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" xml:lang="en">
# <head>
# <title>Academic Calendar &lt; University of Illinois Chicago</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/search/opensearch.xml" rel="search" title="Catalog" type="application/opensearchdescription+xml"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/css/reset.css" rel="stylesheet" type="text/css"/>
# <link href="/css/courseleaf.css" rel="stylesheet" type="text/css"/>
# <link href="/fonts/font-awesome/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="/css/screen.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/css/handheld.css" media="only screen and (max-width: 767px)" rel="stylesheet" type="text/css"/>
# <link href="/css/print.css" media="print" rel="stylesheet" type="text/css"/>
# <script src="/js/jquery.js" type="text/javascript"></script>
# <script src="/js/lfjs.js" type="text/javascript"></script>
# <script src="/js/lfjs_any.js" type="text/javascript"></script>
# <link href="/js/lfjs.css" rel="stylesheet" type="text/css"/>
# <script src="/js/courseleaf.js" type="text/javascript"></script>
# <script src="/js/custom.js" type="text/javascript"></script>
# </head>
# <body>
# <!--htdig_noindex-->
# <div class="accessible noscript">
# <div aria-label="Accessible Navigation" class="accessible-menu" role="navigation">
# <ul>
# <li><a href="#content" rel="section">Skip to Content</a></li>
# <li><a href="/azindex/">AZ Index</a></li>
# <li><a href="/">Catalog Home</a></li>
# <li><a href="http://www.uic.edu">UIC Home</a></li>
# </ul>
# </div>
# </div>
# <!--/htdig_noindex-->
# <header id="header-new">
# <div class="wrap">
# <div class="logo-header">
# <a href="//www.uic.edu">
# <img alt="University of Illinois Chicago" src="/images/logo2021.png"/>
# </a>
# </div>
# <nav aria-label="catalog quicklink" class="catalog-quicklinks">
# <button aria-controls="mobile-menu" aria-expanded="false" data-toggle="#mobile-menu" id="hamburger">
# <span class="sr-only">Toggle menu</span>
# <i aria-hidden="true" class="fa fa-bars"></i>
# </button>
# <div id="mobile-menu">
# <ul id="quicklinks">
# <li><a href="/ucat/">Undergraduate</a></li>
# <li><a href="/gcat">Graduate</a></li>
# <li><a href="#" onclick="showPrintDialog(); return false;">Print / Download Options</a></li>
# </ul>
# <div id="search" role="search">
# <form action="/search/" class="clearfix" id="cl-search">
# <label for="name">Search Catalog</label>
# <input class="searchbox" id="name" name="search" placeholder="Search catalog..." size="25" title="Search Catalog" type="text"/>
# <input class="submit" type="submit" value="Search"/>
# <input name="fscaturl" type="hidden" value="/ucat"/><input name="gscaturl" type="hidden" value="/ucat"/> </form>
# </div><!-- end #search -->
# </div><!-- /#mobile-menu -->
# </nav>
# </div>
# </header>
# <!--htdig_noindex-->
# <div id="header" role="header">
# <div class="wrap clearfix">
# <a href="/">
# <h1>Academic Catalog</h1>
# </a>
# </div><!--end .wrap -->
# </div><!-- end #header -->
# <!--/htdig_noindex-->
# <!--htdig_noindex-->
# <section aria-labbledby="banner-header" class="ugrad" id="banner">
# <div class="wrap">
# <div class="banner-text">
# <h2 id="banner-header">2021-2023 Undergraduate Catalog</h2>
# </div>
# </div><!--end .wrap -->
# </section><!--end #navigation -->
# <!--/htdig_noindex-->
# <div id="wrapper">
# <div class="clearfix" id="container">
# <div id="nav-col" role="complementary">
# <a class="togglenav" href="#" id="cl-menu-control">
# <span class="cl-menu-text">Catalog Navigation</span>
# <!-- <a class="cl-menu-btn" href="#">Catalog Navigation</a> -->
# <svg aria-label="Down arrow icon" height="32" role="presentation" viewbox="0 0 32 32" width="32"><title>Down arrow icon</title><g fill="none" fill-rule="evenodd"><circle class="_circle" cx="16" cy="16" fill="#fff" r="15" stroke="#007Da5" stroke-width="1"></circle><path class="_arrow" d="M12 17l4 4 4-4M16 20v-9" stroke="#001E62" stroke-linecap="round" stroke-width="2"></path></g></svg>
# </a><!--end #cl-menu-control-->
# <!-- Begin Regular Nav -->
# <div aria-label="Secondary Navigation" id="cl-menu" role="navigation">
# <ul class="nav levelzero" id="/">
# <li class="active isparent"><a href="/ucat/">Undergraduate Catalog</a>
# <ul class="nav levelone" id="/ucat/">
# <li class="active self"><a href="#" onclick="return false;">Academic Calendar</a></li>
# <li class="isparent"><a href="/ucat/the-university/">The University</a></li>
# <li class="isparent"><a href="/ucat/admissions-registration-finances/">Admissions, Registration &amp;​ Finances</a></li>
# <li class="isparent"><a href="/ucat/degree-programs/">Degree Programs and Requirements</a></li>
# <li class="isparent"><a href="/ucat/colleges-depts/">Colleges &amp;​ Departments</a></li>
# <li class="isparent"><a href="/ucat/course-descriptions/">Undergraduate Course Descriptions</a></li>
# <li><a href="/ucat/archive-links/">Archive &amp;​ Links</a></li>
# </ul>
# </li>
# <li class="isparent"><a href="/gcat/">Graduate Catalog</a></li>
# <li class="isparent"><a href="/all-course-descriptions/">All Course Descriptions</a></li>
# </ul>
# </div><!--end #cl-menu-->
# <!-- End Nav -->
# </div><!-- end #nav-col -->
# <div id="content-col">
# <div id="content" role="main">
# <div aria-label="Breadcrumb Navigation" class="clearfix" id="breadcrumb" role="navigation">
# <ul><li><a href="/">Home</a><span class="crumbsep">/</span></li><li><a href="/ucat/">Undergraduate Catalog</a><span class="crumbsep">/</span></li><li><span class="active">Academic Calendar</span></li></ul>
# </div><!-- end #breadcrumb -->
# <h1 class="page-title">Academic Calendar</h1>
# <div class="page_content" id="textcontainer">
# <div class="sidebar">
# <div id="sidebar-contact">
# </div>
# </div>
# <p><a href="https://registrar.uic.edu/uic_faculty_staff/calendars/degree_dates.html" target="_blank">Semester Beginning, Ending, and Degree Dates</a><br/>
# <a href="https://registrar.uic.edu/current-students/calendars/admin-calendar/" target="_blank">Administrative Calendar with Add/Drop Deadlines</a></p>
# <h2 class="toggle"><strong>2021-2022 Academic Calendar</strong></h2>
# <h3>Fall Semester 2021</h3>
# <table cellpadding="0" cellspacing="0" class="sc_sctable tbl_ugacademiccalendar" summary="UG Academic Calendar" width="100%">
# <caption class="hidden noscript">UG Academic Calendar</caption>
# <colgroup><col class="column0" pdfwidth="40%" width="40%"/><col class="column1" pdfwidth="60%" width="60%"/></colgroup>
# <thead>
# <tr class="sctablehead">
# <th class="column0" scope="col">Date</th>
# <th class="column1" scope="col">Event</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even firstrow"><td class="column0">August 23, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="odd"><td class="column0">September 5, Su</td>
# <td class="column1">Last day to complete late registration; last day to add a course(s) or make section changes; last day to drop individual courses via XE Registration without receiving W (Withdrawn) grade on academic record. Last day to Web Drop courses via XE Registration and receive 100% cancellation of tuition and fees.</td>
# </tr>
# <tr class="even"><td class="column0">September 6, M</td>
# <td class="column1">Labor Day holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">September 12, Su</td>
# <td class="column1">CampusCare Waiver deadline.</td>
# </tr>
# <tr class="even"><td class="column0">October 29, F</td>
# <td class="column1">Last day for undergraduate students to use optional late drop in college office and receive grade of W on academic record.</td>
# </tr>
# <tr class="odd"><td class="column0">November 25–26, Th–F</td>
# <td class="column1">Thanksgiving holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">December 3, F</td>
# <td class="column1">Instruction ends.</td>
# </tr>
# <tr class="odd"><td class="column0">December 6–10, M–F</td>
# <td class="column1">Final examinations.</td>
# </tr>
# <tr class="even"><td class="column0">December 15, W</td>
# <td class="column1">Instructor grading deadline for 16-week courses (5 p.m.)</td>
# </tr>
# <tr class="odd last lastrow"><td class="column0">December 20, M</td>
# <td class="column1">Grades available via my.UIC.edu</td>
# </tr>
# </tbody>
# </table>
# <h3>Spring Semester 2022</h3>
# <table cellpadding="0" cellspacing="0" class="sc_sctable tbl_ugacademiccalendar" summary="UG Academic Calendar" width="100%">
# <caption class="hidden noscript">UG Academic Calendar</caption>
# <colgroup><col class="column0" pdfwidth="40%" width="40%"/><col class="column1" pdfwidth="60%" width="60%"/></colgroup>
# <thead>
# <tr class="sctablehead">
# <th class="column0" scope="col">Date</th>
# <th class="column1" scope="col">Event</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even firstrow"><td class="column0">January 10, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="odd"><td class="column0">January 17, M</td>
# <td class="column1">Martin Luther King Jr. Day. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">January 21, F</td>
# <td class="column1">Last day to complete late registration; last day to add a course(s) or make section changes; last day to drop individual courses via XE Registration without receiving W (Withdrawn) grade on academic record. Last day to Web Drop courses via XE Registration and receive 100% cancellation of tuition and fees.</td>
# </tr>
# <tr class="odd"><td class="column0">February 6, Su</td>
# <td class="column1">CampusCare Waiver deadline.</td>
# </tr>
# <tr class="even"><td class="column0">March 18, F</td>
# <td class="column1">Last day for undergraduate students to use optional late drop in college office and receive grade of W on academic record.</td>
# </tr>
# <tr class="odd"><td class="column0">March 21–25, M–F</td>
# <td class="column1">Spring vacation. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">April 29, F</td>
# <td class="column1">Instruction ends.</td>
# </tr>
# <tr class="odd"><td class="column0">May 2–6, M–F</td>
# <td class="column1">Final examinations.</td>
# </tr>
# <tr class="even"><td class="column0">May 11, W</td>
# <td class="column1">Instructor grading deadline for 16-week courses (5 p.m.)</td>
# </tr>
# <tr class="odd last lastrow"><td class="column0">May 16, M</td>
# <td class="column1">Grades available via my.UIC.edu</td>
# </tr>
# </tbody>
# </table>
# <h3>Summer Session 2022</h3>
# <table cellpadding="0" cellspacing="0" class="sc_sctable tbl_ugacademiccalendar" summary="UG Academic Calendar" width="100%">
# <caption class="hidden noscript">UG Academic Calendar</caption>
# <colgroup><col class="column0" pdfwidth="40%" width="40%"/><col class="column1" pdfwidth="60%" width="60%"/></colgroup>
# <thead>
# <tr class="sctablehead">
# <th class="column0" scope="col">Date</th>
# <th class="column1" scope="col">Event</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even firstrow"><td class="column0"><strong>Summer Session 1</strong></td>
# <td class="column1">(4-Week Session)</td>
# </tr>
# <tr class="odd"><td class="column0">May 16, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">May 18, W</td>
# <td class="column1">Last day to complete late registration for Summer Session 1; last day to add a course(s) or make section changes; last day to drop individual Summer Session 1 courses via XE Registration without receiving W (Withdrawn) grade on academic record. Last day to Web Drop Summer Session 1 courses via XE Registration and receive 100% cancellation of tuition and fees.</td>
# </tr>
# <tr class="odd"><td class="column0">May 30, M</td>
# <td class="column1">Memorial Day holiday. No classes</td>
# </tr>
# <tr class="even"><td class="column0">May 30, M</td>
# <td class="column1">CampusCare Waiver deadline.</td>
# </tr>
# <tr class="odd"><td class="column0">June 1, W</td>
# <td class="column1">Last day for undergraduate students to use optional late drop for a Summer Session 1 course in college office and receive grade of W on academic record.</td>
# </tr>
# <tr class="even"><td class="column0">June 9, Th</td>
# <td class="column1">Instruction ends for Summer Session 1.</td>
# </tr>
# <tr class="odd"><td class="column0">June 10, F</td>
# <td class="column1">Final examinations for Summer Session 1.</td>
# </tr>
# <tr class="even"><td class="column0"><strong>Summer Session 2</strong></td>
# <td class="column1">(8-Week Session)</td>
# </tr>
# <tr class="odd"><td class="column0">June 13, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">June 17, F</td>
# <td class="column1">Juneteenth holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">June 20, M</td>
# <td class="column1">Last day to complete late registration for Summer Session 2; last day to add a course(s) or make section changes; last day to drop individual Summer Session 2 courses via XE Registration without receiving W (Withdrawn) grade on academic record. Last day to Web Drop courses via XE Registration and receive 100% cancellation of tuition and fees.</td>
# </tr>
# <tr class="even"><td class="column0">July 4, M</td>
# <td class="column1">Independence Day holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">July 15, F</td>
# <td class="column1">Last day for undergraduate students to use optional late drop for a Summer Session 2 course in college office and receive grade of W on academic record.</td>
# </tr>
# <tr class="even"><td class="column0">August 3, W</td>
# <td class="column1">Instruction ends for Summer Session 2.</td>
# </tr>
# <tr class="odd last lastrow"><td class="column0">August 4–5, Th–F</td>
# <td class="column1">Final examinations for Summer Session 2.</td>
# </tr>
# </tbody>
# </table>
# <h2 class="toggle"><a id="FALL2022" name="FALL2022"></a>2022-2023 Academic Calendar</h2>
# <table cellpadding="0" cellspacing="0" class="sc_sctable tbl_ugacademiccalendar" summary="UG Academic Calendar" width="100%">
# <caption class="hidden noscript">UG Academic Calendar</caption>
# <colgroup><col class="column0" pdfwidth="40%" width="40%"/><col class="column1" pdfwidth="60%" width="60%"/></colgroup>
# <thead>
# <tr class="sctablehead">
# <th class="column0" scope="col">Date</th>
# <th class="column1" scope="col">Event</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even firstrow"><td class="column0"><strong>Fall Semester 2022</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0">August 22, M</td>
# <td class="column1">Instruction begins. </td>
# </tr>
# <tr class="even"><td class="column0">September 5, M</td>
# <td class="column1">Labor Day holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">October 14, F</td>
# <td class="column1">Eight-week Part of Term A ends.</td>
# </tr>
# <tr class="even"><td class="column0">October 17, M</td>
# <td class="column1">Eight-week Part of Term B begins.</td>
# </tr>
# <tr class="odd"><td class="column0">November 8, T</td>
# <td class="column1">Election Day holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">November 24–25, Th–F</td>
# <td class="column1">Thanksgiving holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">December 2, F</td>
# <td class="column1">Instruction ends.</td>
# </tr>
# <tr class="even"><td class="column0">December 5–9, M–F</td>
# <td class="column1">Final examinations.</td>
# </tr>
# <tr class="odd"><td class="column0">December 14, W</td>
# <td class="column1">Instructor grading deadline for 16-week courses (5 p.m.)</td>
# </tr>
# <tr class="even"><td class="column0">December 19, M</td>
# <td class="column1">Grades available via my.UIC.edu</td>
# </tr>
# <tr class="odd"><td class="column0"><strong>Spring Semester 2023</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="even"><td class="column0">January 9, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="odd"><td class="column0">January 16, M</td>
# <td class="column1">Martin Luther King Jr. Day. No Classes.</td>
# </tr>
# <tr class="even"><td class="column0">March 3, F</td>
# <td class="column1">Eight-week Part of Term A ends.</td>
# </tr>
# <tr class="odd"><td class="column0">March 6, M</td>
# <td class="column1">Eight-week Part of Term B begins.</td>
# </tr>
# <tr class="even"><td class="column0">March 20-24, M-F</td>
# <td class="column1">Spring vacation. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">April 28, F</td>
# <td class="column1">Instruction ends.</td>
# </tr>
# <tr class="even"><td class="column0">May 1-5, M-F</td>
# <td class="column1">Final examinations.</td>
# </tr>
# <tr class="odd"><td class="column0">May 10, W</td>
# <td class="column1">Instructor grading deadline for 16-week courses (5 p.m.)</td>
# </tr>
# <tr class="even"><td class="column0">May 15, M</td>
# <td class="column1">Grades available via my.UIC.edu</td>
# </tr>
# <tr class="odd"><td class="column0"><strong>Summer Sessions 2023</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="even"><td class="column0"><strong>Summer Session 1 (4-Week)</strong> </td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0">May 15, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">May 29, M</td>
# <td class="column1">Memorial Day holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">June 8, Th</td>
# <td class="column1">Instruction ends for Summer Session 1.</td>
# </tr>
# <tr class="even"><td class="column0">June 9, F</td>
# <td class="column1">Final examinations for Summer Session 1.</td>
# </tr>
# <tr class="odd"><td class="column0"><strong>Summer Session 2 (8-Week)</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="even"><td class="column0">June 12, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="odd"><td class="column0">June 19, M</td>
# <td class="column1">Juneteenth holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">July 4, Tu</td>
# <td class="column1">Independence Day holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">August 2, W</td>
# <td class="column1">Instruction ends for Summer Session 2.</td>
# </tr>
# <tr class="even last lastrow"><td class="column0">August 3-4, Th-F</td>
# <td class="column1">Final examinations for Summer Session 2.</td>
# </tr>
# </tbody>
# </table>
# <h2 class="toggle"><strong>2023-2024 Academic Calendar</strong></h2>
# <table cellpadding="0" cellspacing="0" class="sc_sctable tbl_ugacademiccalendar" summary="UG Academic Calendar" width="100%">
# <caption class="hidden noscript">UG Academic Calendar</caption>
# <colgroup><col class="column0" pdfwidth="40%" width="40%"/><col class="column1" pdfwidth="60%" width="60%"/></colgroup>
# <thead>
# <tr class="sctablehead">
# <th class="column0" scope="col">Date</th>
# <th class="column1" scope="col">Event</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even firstrow"><td class="column0"><strong>Fall Semester 2023</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0">August 21, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">September 4, M</td>
# <td class="column1">Labor Day holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">October 13, F</td>
# <td class="column1">Eight-week Part of Term A ends.</td>
# </tr>
# <tr class="even"><td class="column0">October 16, M</td>
# <td class="column1">Eight-week Part of Term B begins.</td>
# </tr>
# <tr class="odd"><td class="column0">November 23–24, Th–F</td>
# <td class="column1">Thanksgiving holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">December 1, F</td>
# <td class="column1">Instruction ends.</td>
# </tr>
# <tr class="odd"><td class="column0">December 4–8, M–F</td>
# <td class="column1">Final examinations.</td>
# </tr>
# <tr class="even"><td class="column0">December 13, W</td>
# <td class="column1">Instructor grading deadline for 16-week courses (5 p.m.)</td>
# </tr>
# <tr class="odd"><td class="column0">December 18, M</td>
# <td class="column1">Grades available via my.UIC.edu</td>
# </tr>
# <tr class="even"><td class="column0"><strong>Spring Semester 2024</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0">January 8, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">January 15, M</td>
# <td class="column1">Martin Luther King Jr. Day. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">March 1, F</td>
# <td class="column1">Eight-week Part of Term A ends.</td>
# </tr>
# <tr class="even"><td class="column0">March 4, M</td>
# <td class="column1">Eight-week Part of Term B begins.</td>
# </tr>
# <tr class="odd"><td class="column0">March 18-22, M-F</td>
# <td class="column1">Spring vacation. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">April 26, F</td>
# <td class="column1">Instruction ends.</td>
# </tr>
# <tr class="odd"><td class="column0">April 29-May 3, M-F</td>
# <td class="column1">Final examinations.</td>
# </tr>
# <tr class="even"><td class="column0">May 8, W</td>
# <td class="column1">Instructor grading deadline for 16-week courses (5 p.m.)</td>
# </tr>
# <tr class="odd"><td class="column0">May 13, M</td>
# <td class="column1">Grades available via my.UIC.edu</td>
# </tr>
# <tr class="even"><td class="column0"><strong>Summer Sessions 2024</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0"><strong>Summer Session 1 (4-week session)</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="even"><td class="column0">May 13, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="odd"><td class="column0">May 27, M</td>
# <td class="column1">Memorial Day holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">June 6, Th</td>
# <td class="column1">Instruction ends for Summer Session 1.</td>
# </tr>
# <tr class="odd"><td class="column0">June 7, F</td>
# <td class="column1">Final examinations for Summer Session 1.</td>
# </tr>
# <tr class="even"><td class="column0"><strong>Summer Session 2 (8-week session)</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0">June 10, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">June 19, W</td>
# <td class="column1">Juneteenth holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">July 4, Th</td>
# <td class="column1">Independence Day holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">July 31, W</td>
# <td class="column1">Instruction ends for Summer Session 2.</td>
# </tr>
# <tr class="odd last lastrow"><td class="column0">August 1-2, Th-F</td>
# <td class="column1">Final examinations for Summer Session 2.</td>
# </tr>
# </tbody>
# </table>
# <h2 class="toggle"><strong>2024-2025 Academic Calendar</strong></h2>
# <table cellpadding="0" cellspacing="0" class="sc_sctable tbl_ugacademiccalendar" summary="UG Academic Calendar" width="100%">
# <caption class="hidden noscript">UG Academic Calendar</caption>
# <colgroup><col class="column0" pdfwidth="40%" width="40%"/><col class="column1" pdfwidth="60%" width="60%"/></colgroup>
# <thead>
# <tr class="sctablehead">
# <th class="column0" scope="col">Date</th>
# <th class="column1" scope="col">Event</th>
# </tr>
# </thead>
# <tbody>
# <tr class="even firstrow"><td class="column0"><strong>Fall Semester 2024</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0">August 26, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">September 2, M</td>
# <td class="column1">Labor Day holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">October 11, F</td>
# <td class="column1">Eight-week Part of Term A ends.</td>
# </tr>
# <tr class="even"><td class="column0">October 14, M</td>
# <td class="column1">Eight-week Part of Term B begins.</td>
# </tr>
# <tr class="odd"><td class="column0">November 28–29, Th–F</td>
# <td class="column1">Thanksgiving holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">December 6, F</td>
# <td class="column1">Instruction ends.</td>
# </tr>
# <tr class="odd"><td class="column0">December 9–13, M–F</td>
# <td class="column1">Final examinations.</td>
# </tr>
# <tr class="even"><td class="column0">December 18, W</td>
# <td class="column1">Instructor grading deadline for 16-week courses (5 p.m.)</td>
# </tr>
# <tr class="odd"><td class="column0">December 23, M</td>
# <td class="column1">Grades available via my.UIC.edu</td>
# </tr>
# <tr class="even"><td class="column0"><strong>Spring Semester 2025</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0">January 13, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">January 20, M</td>
# <td class="column1">Martin Luther King Jr. Day. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">March 7, F</td>
# <td class="column1">Eight-week Part of Term A ends.</td>
# </tr>
# <tr class="even"><td class="column0">March 10, M</td>
# <td class="column1">Eight-week Part of Term B begins.</td>
# </tr>
# <tr class="odd"><td class="column0">March 24-28, M-F</td>
# <td class="column1">Spring vacation. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">May 2, F</td>
# <td class="column1">Instruction ends.</td>
# </tr>
# <tr class="odd"><td class="column0">May 5-9, M-F</td>
# <td class="column1">Final examinations.</td>
# </tr>
# <tr class="even"><td class="column0">May 14, W</td>
# <td class="column1">Instructor grading deadline for 16-week courses (5 p.m.)</td>
# </tr>
# <tr class="odd"><td class="column0">May 19, M</td>
# <td class="column1">Grades available via my.UIC.edu</td>
# </tr>
# <tr class="even"><td class="column0"><strong>Summer Sessions 2025</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0"><strong>Summer Session 1 (4-week session)</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="even"><td class="column0">May 19, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="odd"><td class="column0">May 26, M</td>
# <td class="column1">Memorial Day holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">June 12, Th</td>
# <td class="column1">Instruction ends for Summer Session 1.</td>
# </tr>
# <tr class="odd"><td class="column0">June 13, F</td>
# <td class="column1">Final examinations for Summer Session 1.</td>
# </tr>
# <tr class="even"><td class="column0"><strong>Summer Session 2 (8-week session)</strong></td>
# <td class="column1"></td>
# </tr>
# <tr class="odd"><td class="column0">June 16, M</td>
# <td class="column1">Instruction begins.</td>
# </tr>
# <tr class="even"><td class="column0">June 19, Th</td>
# <td class="column1">Juneteenth holiday. No classes.</td>
# </tr>
# <tr class="odd"><td class="column0">July 4, F</td>
# <td class="column1">Independence Day holiday. No classes.</td>
# </tr>
# <tr class="even"><td class="column0">August 6, W</td>
# <td class="column1">Instruction ends for Summer Session 2.</td>
# </tr>
# <tr class="odd last lastrow"><td class="column0">August 7-8, Th-F</td>
# <td class="column1">Final examinations for Summer Session 2.</td>
# </tr>
# </tbody>
# </table>
# </div><!--end #textcontainer -->
# </div> <!-- end #content -->
# </div><!--end #content-col -->
# </div><!-- end #container -->
# </div><!-- end #wrapper -->
# <div class="clearfix" id="footer" role="contentinfo">
# <div class="wrap">
# <div id="foot-logo">
# <a href="/">University of Illinois Chicago</a>
# </div><!-- end #foot-logo -->
# <p><a href="http://admissions.uic.edu/apply-now">Apply Online</a> | <a href="http://admissions.uic.edu/contact-admissions">Contact Admissions</a> | <a href="https://www.vpaa.uillinois.edu/resources/web_privacy">Privacy Statement</a><br/>
#         Having problems accessing this site? <a href="mailto:ccmelby@uic.edu">Contact the Webmaster</a>.<br/>
#         © 2021-2023 The Board of Trustees of the University of Illinois</p>
# </div>
# </div><!-- end #footer -->
# <a href="#header" id="totop">Back to Top</a>
# <div aria-labeledby="dialog-title" class="screen" id="print-dialog" role="dialog">
# <div class="print-header">
# <h2 id="dialog-title">Print Options</h2>
# </div>
# <div class="print-body">
# <div class="print-option">
# <div class="option-head">
# <a href="#" onclick="hidePrintDialog();window.print();return false">Send Page to Printer</a>
# </div>
# <p>
# <em>Print this page.</em>
# </p>
# </div>
# <div class="print-option"><div class="option-head"><a class="option-name" href="/ucat/academic-calendar/academic-calendar.pdf" role="button">Download Page (PDF)</a></div><p class="option-desc"><em>The PDF will include all information unique to this page.</em></p></div><div class="print-option"><div class="option-head"><a class="option-name" href="/pdf/2021-23-undergraduate.pdf" target="_blank">Download PDF of the entire Undergraduate Catalog</a></div><p class="option-desc"><em>All pages in the campus catalog.</em></p></div> </div>
# <div class="buttons clearfix">
# <div class="cancel">
# <a href="#" onclick="hidePrintDialog(); return false;">Cancel</a>
# </div>
# </div>
# </div>
# </body>
# </html>

# %%
tables = soup.find_all("table")

# %%
len(tables)
# Out:
# 6

# %%
good_tables = tables[3:]  # Drop the 2021-2022 academic year when they marked everything up differently (?!?!?!)

# %%
for t in good_tables:
    for row in t.find_all("tr"):
        print(row.text)
# Out:
# Date
# Event
#
# Fall Semester 2022
#
#
# August 22, M
# Instruction begins.
#
# September 5, M
# Labor Day holiday. No classes.
#
# October 14, F
# Eight-week Part of Term A ends.
#
# October 17, M
# Eight-week Part of Term B begins.
#
# November 8, T
# Election Day holiday. No classes.
#
# November 24–25, Th–F
# Thanksgiving holiday. No classes.
#
# December 2, F
# Instruction ends.
#
# December 5–9, M–F
# Final examinations.
#
# December 14, W
# Instructor grading deadline for 16-week courses (5 p.m.)
#
# December 19, M
# Grades available via my.UIC.edu
#
# Spring Semester 2023
#
#
# January 9, M
# Instruction begins.
#
# January 16, M
# Martin Luther King Jr. Day. No Classes.
#
# March 3, F
# Eight-week Part of Term A ends.
#
# March 6, M
# Eight-week Part of Term B begins.
#
# March 20-24, M-F
# Spring vacation. No classes.
#
# April 28, F
# Instruction ends.
#
# May 1-5, M-F
# Final examinations.
#
# May 10, W
# Instructor grading deadline for 16-week courses (5 p.m.)
#
# May 15, M
# Grades available via my.UIC.edu
#
# Summer Sessions 2023
#
#
# Summer Session 1 (4-Week)
#
#
# May 15, M
# Instruction begins.
#
# May 29, M
# Memorial Day holiday. No classes.
#
# June 8, Th
# Instruction ends for Summer Session 1.
#
# June 9, F
# Final examinations for Summer Session 1.
#
# Summer Session 2 (8-Week)
#
#
# June 12, M
# Instruction begins.
#
# June 19, M
# Juneteenth holiday. No classes.
#
# July 4, Tu
# Independence Day holiday. No classes.
#
# August 2, W
# Instruction ends for Summer Session 2.
#
# August 3-4, Th-F
# Final examinations for Summer Session 2.
#
#
# Date
# Event
#
# Fall Semester 2023
#
#
# August 21, M
# Instruction begins.
#
# September 4, M
# Labor Day holiday. No classes.
#
# October 13, F
# Eight-week Part of Term A ends.
#
# October 16, M
# Eight-week Part of Term B begins.
#
# November 23–24, Th–F
# Thanksgiving holiday. No classes.
#
# December 1, F
# Instruction ends.
#
# December 4–8, M–F
# Final examinations.
#
# December 13, W
# Instructor grading deadline for 16-week courses (5 p.m.)
#
# December 18, M
# Grades available via my.UIC.edu
#
# Spring Semester 2024
#
#
# January 8, M
# Instruction begins.
#
# January 15, M
# Martin Luther King Jr. Day. No classes.
#
# March 1, F
# Eight-week Part of Term A ends.
#
# March 4, M
# Eight-week Part of Term B begins.
#
# March 18-22, M-F
# Spring vacation. No classes.
#
# April 26, F
# Instruction ends.
#
# April 29-May 3, M-F
# Final examinations.
#
# May 8, W
# Instructor grading deadline for 16-week courses (5 p.m.)
#
# May 13, M
# Grades available via my.UIC.edu
#
# Summer Sessions 2024
#
#
# Summer Session 1 (4-week session)
#
#
# May 13, M
# Instruction begins.
#
# May 27, M
# Memorial Day holiday. No classes.
#
# June 6, Th
# Instruction ends for Summer Session 1.
#
# June 7, F
# Final examinations for Summer Session 1.
#
# Summer Session 2 (8-week session)
#
#
# June 10, M
# Instruction begins.
#
# June 19, W
# Juneteenth holiday. No classes.
#
# July 4, Th
# Independence Day holiday. No classes.
#
# July 31, W
# Instruction ends for Summer Session 2.
#
# August 1-2, Th-F
# Final examinations for Summer Session 2.
#
#
# Date
# Event
#
# Fall Semester 2024
#
#
# August 26, M
# Instruction begins.
#
# September 2, M
# Labor Day holiday. No classes.
#
# October 11, F
# Eight-week Part of Term A ends.
#
# October 14, M
# Eight-week Part of Term B begins.
#
# November 28–29, Th–F
# Thanksgiving holiday. No classes.
#
# December 6, F
# Instruction ends.
#
# December 9–13, M–F
# Final examinations.
#
# December 18, W
# Instructor grading deadline for 16-week courses (5 p.m.)
#
# December 23, M
# Grades available via my.UIC.edu
#
# Spring Semester 2025
#
#
# January 13, M
# Instruction begins.
#
# January 20, M
# Martin Luther King Jr. Day. No classes.
#
# March 7, F
# Eight-week Part of Term A ends.
#
# March 10, M
# Eight-week Part of Term B begins.
#
# March 24-28, M-F
# Spring vacation. No classes.
#
# May 2, F
# Instruction ends.
#
# May 5-9, M-F
# Final examinations.
#
# May 14, W
# Instructor grading deadline for 16-week courses (5 p.m.)
#
# May 19, M
# Grades available via my.UIC.edu
#
# Summer Sessions 2025
#
#
# Summer Session 1 (4-week session)
#
#
# May 19, M
# Instruction begins.
#
# May 26, M
# Memorial Day holiday. No classes.
#
# June 12, Th
# Instruction ends for Summer Session 1.
#
# June 13, F
# Final examinations for Summer Session 1.
#
# Summer Session 2 (8-week session)
#
#
# June 16, M
# Instruction begins.
#
# June 19, Th
# Juneteenth holiday. No classes.
#
# July 4, F
# Independence Day holiday. No classes.
#
# August 6, W
# Instruction ends for Summer Session 2.
#
# August 7-8, Th-F
# Final examinations for Summer Session 2.

# %%
# Output format: I want each event on the calendar to become a dictionary
# like this one:
{
    "year": 2023,
    "term": "spring",  # or "summer 1" or "summer 2" or "fall"
    "date": "April 28, F",
    "event": "Instruction ends."
}

# %%
# ASSUMPTION: Any row of a schedule table that has its first <td>
# containing the word "summer", "spring", or "fall" is a heading
# indicating a new year/term.
def is_term_heading(row):
    first_td = row.td
    if first_td==None:
        return False
    s = first_td.text.lower()
    if "summer" in s or "fall" in s or "spring" in s:
        return True
    return False

# %%
schedule_events = []

for t in good_tables:
    for row in t.find_all("tr"):
        if is_term_heading(row):
            s = row.text.lower()
            fields = s.split()
            try:
                # If this works, then we're seeing something like "Fall Semester 2022"
                year = int(fields[-1]) # e.g. 2022
                term = fields[0].lower() # e.g. "fall"
            except ValueError:
                # We're seeing something like "Summer Session 1 (4-Week)"
                if s.startswith("summer session 1"):
                    term = "summer1"
                else:
                    term = "summer2"
            print(year,term)
        else:
            heading = row.find("th")
            if heading != None:
                continue # skip all rows that give column headings
            #e.g. "December 8, F.  Instruction Ends."
            # record this schedule item
            cells = row.find_all("td")
            schedule_events.append(
                {
                    "year": year,
                    "term": term,
                    "date": cells[0].text, # content of the first td
                    "event": cells[1].text, # context of the second td 
                }
            )
# Out:
# 2022 fall
# 2023 spring
# 2023 summer
# 2023 summer1
# 2023 summer2
# 2023 fall
# 2024 spring
# 2024 summer
# 2024 summer1
# 2024 summer2
# 2024 fall
# 2025 spring
# 2025 summer
# 2025 summer1
# 2025 summer2

# %%
schedule_events
# Out:
# [{'year': 2022,
#   'term': 'fall',
#   'date': 'August 22, M',
#   'event': 'Instruction begins. '},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'September 5, M',
#   'event': 'Labor Day holiday. No classes.'},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'October 14, F',
#   'event': 'Eight-week Part of Term A ends.'},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'October 17, M',
#   'event': 'Eight-week Part of Term B begins.'},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'November 8, T',
#   'event': 'Election Day holiday. No classes.'},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'November 24–25, Th–F',
#   'event': 'Thanksgiving holiday. No classes.'},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'December 2, F',
#   'event': 'Instruction ends.'},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'December 5–9, M–F',
#   'event': 'Final examinations.'},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'December 14, W',
#   'event': 'Instructor grading deadline for 16-week courses (5 p.m.)'},
#  {'year': 2022,
#   'term': 'fall',
#   'date': 'December 19, M',
#   'event': 'Grades available via my.UIC.edu'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'January 9, M',
#   'event': 'Instruction begins.'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'January 16, M',
#   'event': 'Martin Luther King Jr. Day. No Classes.'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'March 3, F',
#   'event': 'Eight-week Part of Term A ends.'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'March 6, M',
#   'event': 'Eight-week Part of Term B begins.'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'March 20-24, M-F',
#   'event': 'Spring vacation. No classes.'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'April 28, F',
#   'event': 'Instruction ends.'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'May 1-5, M-F',
#   'event': 'Final examinations.'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'May 10, W',
#   'event': 'Instructor grading deadline for 16-week courses (5 p.m.)'},
#  {'year': 2023,
#   'term': 'spring',
#   'date': 'May 15, M',
#   'event': 'Grades available via my.UIC.edu'},
#  {'year': 2023,
#   'term': 'summer1',
#   'date': 'May 15, M',
#   'event': 'Instruction begins.'},
#  {'year': 2023,
#   'term': 'summer1',
#   'date': 'May 29, M',
#   'event': 'Memorial Day holiday. No classes.'},
#  {'year': 2023,
#   'term': 'summer1',
#   'date': 'June 8, Th',
#   'event': 'Instruction ends for Summer Session 1.'},
#  {'year': 2023,
#   'term': 'summer1',
#   'date': 'June 9, F',
#   'event': 'Final examinations for Summer Session 1.'},
#  {'year': 2023,
#   'term': 'summer2',
#   'date': 'June 12, M',
#   'event': 'Instruction begins.'},
#  {'year': 2023,
#   'term': 'summer2',
#   'date': 'June 19, M',
#   'event': 'Juneteenth holiday. No classes.'},
#  {'year': 2023,
#   'term': 'summer2',
#   'date': 'July 4, Tu',
#   'event': 'Independence Day holiday. No classes.'},
#  {'year': 2023,
#   'term': 'summer2',
#   'date': 'August 2, W',
#   'event': 'Instruction ends for Summer Session 2.'},
#  {'year': 2023,
#   'term': 'summer2',
#   'date': 'August 3-4, Th-F',
#   'event': 'Final examinations for Summer Session 2.'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'August 21, M',
#   'event': 'Instruction begins.'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'September 4, M',
#   'event': 'Labor Day holiday. No classes.'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'October 13, F',
#   'event': 'Eight-week Part of Term A ends.'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'October 16, M',
#   'event': 'Eight-week Part of Term B begins.'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'November 23–24, Th–F',
#   'event': 'Thanksgiving holiday. No classes.'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'December 1, F',
#   'event': 'Instruction ends.'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'December 4–8, M–F',
#   'event': 'Final examinations.'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'December 13, W',
#   'event': 'Instructor grading deadline for 16-week courses (5 p.m.)'},
#  {'year': 2023,
#   'term': 'fall',
#   'date': 'December 18, M',
#   'event': 'Grades available via my.UIC.edu'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'January 8, M',
#   'event': 'Instruction begins.'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'January 15, M',
#   'event': 'Martin Luther King Jr. Day. No classes.'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'March 1, F',
#   'event': 'Eight-week Part of Term A ends.'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'March 4, M',
#   'event': 'Eight-week Part of Term B begins.'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'March 18-22, M-F',
#   'event': 'Spring vacation. No classes.'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'April 26, F',
#   'event': 'Instruction ends.'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'April 29-May 3, M-F',
#   'event': 'Final examinations.'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'May 8, W',
#   'event': 'Instructor grading deadline for 16-week courses (5 p.m.)'},
#  {'year': 2024,
#   'term': 'spring',
#   'date': 'May 13, M',
#   'event': 'Grades available via my.UIC.edu'},
#  {'year': 2024,
#   'term': 'summer1',
#   'date': 'May 13, M',
#   'event': 'Instruction begins.'},
#  {'year': 2024,
#   'term': 'summer1',
#   'date': 'May 27, M',
#   'event': 'Memorial Day holiday. No classes.'},
#  {'year': 2024,
#   'term': 'summer1',
#   'date': 'June 6, Th',
#   'event': 'Instruction ends for Summer Session 1.'},
#  {'year': 2024,
#   'term': 'summer1',
#   'date': 'June 7, F',
#   'event': 'Final examinations for Summer Session 1.'},
#  {'year': 2024,
#   'term': 'summer2',
#   'date': 'June 10, M',
#   'event': 'Instruction begins.'},
#  {'year': 2024,
#   'term': 'summer2',
#   'date': 'June 19, W',
#   'event': 'Juneteenth holiday. No classes.'},
#  {'year': 2024,
#   'term': 'summer2',
#   'date': 'July 4, Th',
#   'event': 'Independence Day holiday. No classes.'},
#  {'year': 2024,
#   'term': 'summer2',
#   'date': 'July 31, W',
#   'event': 'Instruction ends for Summer Session 2.'},
#  {'year': 2024,
#   'term': 'summer2',
#   'date': 'August 1-2, Th-F',
#   'event': 'Final examinations for Summer Session 2.'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'August 26, M',
#   'event': 'Instruction begins.'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'September 2, M',
#   'event': 'Labor Day holiday. No classes.'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'October 11, F',
#   'event': 'Eight-week Part of Term A ends.'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'October 14, M',
#   'event': 'Eight-week Part of Term B begins.'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'November 28–29, Th–F',
#   'event': 'Thanksgiving holiday. No classes.'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'December 6, F',
#   'event': 'Instruction ends.'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'December 9–13, M–F',
#   'event': 'Final examinations.'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'December 18, W',
#   'event': 'Instructor grading deadline for 16-week courses (5 p.m.)'},
#  {'year': 2024,
#   'term': 'fall',
#   'date': 'December 23, M',
#   'event': 'Grades available via my.UIC.edu'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'January 13, M',
#   'event': 'Instruction begins.'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'January 20, M',
#   'event': 'Martin Luther King Jr. Day. No classes.'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'March 7, F',
#   'event': 'Eight-week Part of Term A ends.'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'March 10, M',
#   'event': 'Eight-week Part of Term B begins.'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'March 24-28, M-F',
#   'event': 'Spring vacation. No classes.'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'May 2, F',
#   'event': 'Instruction ends.'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'May 5-9, M-F',
#   'event': 'Final examinations.'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'May 14, W',
#   'event': 'Instructor grading deadline for 16-week courses (5 p.m.)'},
#  {'year': 2025,
#   'term': 'spring',
#   'date': 'May 19, M',
#   'event': 'Grades available via my.UIC.edu'},
#  {'year': 2025,
#   'term': 'summer1',
#   'date': 'May 19, M',
#   'event': 'Instruction begins.'},
#  {'year': 2025,
#   'term': 'summer1',
#   'date': 'May 26, M',
#   'event': 'Memorial Day holiday. No classes.'},
#  {'year': 2025,
#   'term': 'summer1',
#   'date': 'June 12, Th',
#   'event': 'Instruction ends for Summer Session 1.'},
#  {'year': 2025,
#   'term': 'summer1',
#   'date': 'June 13, F',
#   'event': 'Final examinations for Summer Session 1.'},
#  {'year': 2025,
#   'term': 'summer2',
#   'date': 'June 16, M',
#   'event': 'Instruction begins.'},
#  {'year': 2025,
#   'term': 'summer2',
#   'date': 'June 19, Th',
#   'event': 'Juneteenth holiday. No classes.'},
#  {'year': 2025,
#   'term': 'summer2',
#   'date': 'July 4, F',
#   'event': 'Independence Day holiday. No classes.'},
#  {'year': 2025,
#   'term': 'summer2',
#   'date': 'August 6, W',
#   'event': 'Instruction ends for Summer Session 2.'},
#  {'year': 2025,
#   'term': 'summer2',
#   'date': 'August 7-8, Th-F',
#   'event': 'Final examinations for Summer Session 2.'}]

# %%
# Write as a CSV
import csv

with open("calendar.csv","wt",newline="") as fp:
    writer = csv.DictWriter(fp,fieldnames=["year","term","date","event"])
    writer.writeheader()
    for d in schedule_events:
        writer.writerow(d)

# %%
# Write as JSON (nice because it preserves data types)
import json

with open("calendar.json","w") as fp:
    json.dump(schedule_events,fp)
