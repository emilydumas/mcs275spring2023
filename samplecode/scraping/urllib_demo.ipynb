# %% [markdown]
# ## Making a simple HTTP request

# %%
from urllib.request import urlopen

# %%
r = urlopen("http://example.com/")

# %%
r.status
# Out:
# 200

# %%
r.headers["Content-Type"]
# Out:
# 'text/html; charset=UTF-8'

# %%
dict(r.headers)
# Out:
# {'Age': '279480',
#  'Cache-Control': 'max-age=604800',
#  'Content-Type': 'text/html; charset=UTF-8',
#  'Date': 'Mon, 17 Apr 2023 18:23:39 GMT',
#  'Etag': '"3147526947+ident"',
#  'Expires': 'Mon, 24 Apr 2023 18:23:39 GMT',
#  'Last-Modified': 'Thu, 17 Oct 2019 07:18:26 GMT',
#  'Server': 'ECS (chb/02C0)',
#  'Vary': 'Accept-Encoding',
#  'X-Cache': 'HIT',
#  'Content-Length': '1256',
#  'Connection': 'close'}

# %%
html_bytes = r.read()

# %%
type(html_bytes)
# Out:
# bytes

# %%
html_bytes[0]
# Out:
# 60

# %%
chr(60)
# Out:
# '<'

# %%
html_bytes
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n  
# ...

# %%
r.headers.get_content_charset()
# Out:
# 'utf-8'

# %%
html = html_bytes.decode(r.headers.get_content_charset())

# %%
html
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
print(html)
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# ...

# %% [markdown]
# ## Making a request to a JSON API

# %%
r = urlopen("https://www.boredapi.com/api/activity")

# %%
r.status
# Out:
# 200

# %%
import json

# %%
data = json.load(r) # one time operation: will consume all the data

# %%
data
# Out:
# {'activity': 'Make a couch fort',
#  'type': 'recreational',
#  'participants': 1,
#  'price': 0,
#  'link': '',
#  'key': '2352669',
#  'accessibility': 0.08}

# %%
r.close()

# %% [markdown]
# ## Requesting an image

# %%
import PIL.Image

# %%
with urlopen("https://picsum.photos/400/300") as r:
    img = PIL.Image.open(r)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300 at 0x7F6AFB95FDF0>

# %%
img.size
# Out:
# (400, 300)

# %%
img.mode
# Out:
# 'RGB'

# %%
img.getpixel((100,150))
# Out:
# (243, 242, 247)

# %% [markdown]
# ## Level 0 HTML Parsing: Just treat it as a string

# %%
# still contains the example.com home page
html
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
html.find("<title>")
# Out:
# 34

# %%
html.find("</title>")
# Out:
# 55

# %%
html[34+7:55]
# Out:
# 'Example Domain'

# %%
with urlopen("http://www.dumas.io/teaching/2023/spring/mcs275/slides/lecture36.html") as r:
    html = r.read().decode( r.headers.get_content_charset("utf-8") )

# %%
a = html.find("<title>")
b = html.find("</title>")

# %%
a,b
# Out:
# (173, 201)

# %%
html[a+7:b]
# Out:
# 'Lec 36: HTTP Requests'

# %% [markdown]
# <title attr1=val1 attr2=val2>
